# %% [markdown]
# # House 1 - 63 jours

# %% [markdown]
# ## Librairie

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from datetime import date

# %% [markdown]
# ## Labels

# %%
h1_labels = pd.read_table('house1_labels.txt', header=None)

# Modifions légérement les labels pour les adapter aux titres des graphiques à venir

h1_labels = pd.DataFrame(h1_labels.iloc[:,0].apply(lambda x: x.replace('&','').replace('-',' ')))
h1_labels = pd.DataFrame(h1_labels.iloc[:,0].apply(lambda x: x.split('(')[0].strip()))
h1_labels = pd.DataFrame(h1_labels.iloc[:,0].apply(lambda x: ' '.join(x.split(' ')[:6])))
h1_labels = pd.DataFrame(h1_labels.iloc[:,0].apply(lambda x: ' '.join(x.split())))
h1_labels
# Out:
#                                     0
# 0              1 Kitchen Wall Oven L1
# 1              2 Kitchen Wall Oven L2
# 2          3 Kitchen Counter Plugs L1
# 3          4 Kitchen Counter Plugs L2
# 4                  5 Clothes Dryer L1
# 5                  6 Clothes Dryer L2
# 6   7 Upstairs Bedroom AFCI Arc Fault
# 7                    8 Kitchen Fridge
# 8                    9 Clothes Washer
# 9               10 Kitchen Dishwasher
# 10          11 Furnace Hot Water Unit
# 11           12 Basement Plugs Lights
# 12                    13 Heat Pump L1
# 13                    14 Heat Pump L2
# 14             15 Garage Sub Panel L1
# 15             16 Garage Sub Panel L2
# 16        17 Upstairs Plugs Lights L1
# 17        18 Upstairs Plugs Lights L2
# 18             19 Basement Blue Plugs
# 19                       20 Bathrooms
# 20       21 Rental Suite Sub Panel L1
# 21       22 Rental Suite Sub Panel L2
# 22                     23 Misc. Plugs
# 23                     24 Home Office

# %% [markdown]
# ## house_energy_blk2 - house 1 - 2016-03-06 to 2016-05-07, 63 days

# %%
h1eb2 = pd.read_csv('house1_energy_blk2.csv')

# Nous renommons les colonnes de notre dataframe

l = h1_labels.iloc[:,0].tolist()

for i in range(len(l)):
    n = i + 1
    s = 'sub'+str(n)
    d = {s:l[i]}
    h1eb2.rename(columns=d, inplace=True)
    
# Convertissons la colonne unix_ts en datetime et passons cette colonne en index

h1eb2 = h1eb2.astype({"unix_ts": int})
h1eb2['unix_ts'] = pd.to_datetime(h1eb2['unix_ts'], unit='s')
h1eb2 = h1eb2.set_index('unix_ts', drop=False)

h1eb2.head(3)
# Out:
#                                 unix_ts  ihd  mains  1 Kitchen Wall Oven L1  \
# unix_ts
# 2016-03-06 08:00:00 2016-03-06 08:00:00  0.5  0.536                     0.0
# 2016-03-06 09:00:00 2016-03-06 09:00:00  0.6  0.557                     0.0
# 2016-03-06 10:00:00 2016-03-06 10:00:00  0.6  0.595                     0.0
#
#                      2 Kitchen Wall Oven L2  3 Kitchen Counter Plugs L1  \
# unix_ts
# 2016-03-06 08:00:00                   0.002                         0.0
# 2016-03-06 09:00:00                   0.001                         0.0
# 2016-03-06 10:00:00                   0.001                         0.0
#
#                      4 Kitchen Counter Plugs L2  5 Clothes Dryer L1  \
# unix_ts
# 2016-03-06 08:00:00                       0.002               0.000
# 2016-03-06 09:00:00                       0.002               0.001
# 2016-03-06 10:00:00                       0.002               0.001
#
#                      6 Clothes Dryer L2  7 Upstairs Bedroom AFCI Arc Fault  \
# unix_ts
# 2016-03-06 08:00:00               0.000                              0.006
# 2016-03-06 09:00:00               0.000                              0.006
# 2016-03-06 10:00:00               0.001                              0.006
#
#                      ...  15 Garage Sub Panel L1  16 Garage Sub Panel L2  \
# unix_ts              ...
# 2016-03-06 08:00:00  ...                   0.000                     0.0
# 2016-03-06 09:00:00  ...                   0.001                     0.0
# 2016-03-06 10:00:00  ...                   0.000                     0.0
#
#                      17 Upstairs Plugs Lights L1  18 Upstairs Plugs Lights L2  \
# unix_ts
# 2016-03-06 08:00:00                        0.005                        0.004
# 2016-03-06 09:00:00                        0.005                        0.004
# 2016-03-06 10:00:00                        0.005                        0.004
#
#                      19 Basement Blue Plugs  20 Bathrooms  \
# unix_ts
# 2016-03-06 08:00:00                   0.021         0.022
# 2016-03-06 09:00:00                   0.020         0.023
# 2016-03-06 10:00:00                   0.021         0.042
#
#                      21 Rental Suite Sub Panel L1  \
# unix_ts
# 2016-03-06 08:00:00                         0.044
# 2016-03-06 09:00:00                         0.045
# 2016-03-06 10:00:00                         0.044
#
#                      22 Rental Suite Sub Panel L2  23 Misc. Plugs  \
# unix_ts
# 2016-03-06 08:00:00                         0.041           0.000
# 2016-03-06 09:00:00                         0.046           0.000
# 2016-03-06 10:00:00                         0.050           0.001
#
#                      24 Home Office
# unix_ts
# 2016-03-06 08:00:00           0.081
# 2016-03-06 09:00:00           0.081
# 2016-03-06 10:00:00           0.082
#
# [3 rows x 27 columns]

# %% [markdown]
# ## Représentations graphiques PART_I

# %%
df = h1eb2.iloc[:,3:].copy()

for i in range(df.shape[1]):
    fig = df[df.columns[i]].plot(figsize=(15,5), title=df.columns[i])
    fig.axes.title.set_size(20)
    plt.show()

# %% [markdown]
# ## Représentations graphiques PART_II

# %%
df1 = h1eb2.iloc[:,2].copy()
fig = df1.plot(figsize=(20,10), title='house_energy_blk2 - house 1 - mains')
fig.axes.title.set_size(20)

# %%
df2 = h1eb2.iloc[:,3:].copy()
fig = df2.plot(figsize=(20,10), title='house_energy_blk2 - house 1 - all sub')
fig.axes.title.set_size(20)

# %% [markdown]
# # ---------------------------------------------------------------

# %% [markdown]
# # ---------------------------------------------------------------

# %% [markdown]
# # ---------------------------------------------------------------

# %% [markdown]
# ## house_power_blk2 - house 1 - 2016-03-06 to 2016-05-07, 63 days

# %%
h1pb2 = pd.read_csv('house1_power_blk2.csv')

# Nous renommons les colonnes de notre dataframe

l = h1_labels.iloc[:,0].tolist()

for i in range(len(l)):
    n = i + 1
    s = 'sub'+str(n)
    d = {s:l[i]}
    h1pb2.rename(columns=d, inplace=True)
    
# Convertissons la colonne unix_ts en datetime et passons cette colonne en index

h1pb2['unix_ts'] = pd.to_datetime(h1pb2['unix_ts'], unit='s')
h1pb2 = h1pb2.set_index('unix_ts', drop=False)

h1pb2.head(3)
# Out:
#                                 unix_ts  ihd  mains  1 Kitchen Wall Oven L1  \
# unix_ts
# 2016-03-06 08:00:00 2016-03-06 08:00:00  NaN  473.0                     0.0
# 2016-03-06 08:00:01 2016-03-06 08:00:01  NaN  474.0                     0.0
# 2016-03-06 08:00:02 2016-03-06 08:00:02  NaN  476.0                     0.0
#
#                      2 Kitchen Wall Oven L2  3 Kitchen Counter Plugs L1  \
# unix_ts
# 2016-03-06 08:00:00                     1.0                         0.0
# 2016-03-06 08:00:01                     1.0                         0.0
# 2016-03-06 08:00:02                     1.0                         0.0
#
#                      4 Kitchen Counter Plugs L2  5 Clothes Dryer L1  \
# unix_ts
# 2016-03-06 08:00:00                         1.0                 0.0
# 2016-03-06 08:00:01                         2.0                 0.0
# 2016-03-06 08:00:02                         2.0                 0.0
#
#                      6 Clothes Dryer L2  7 Upstairs Bedroom AFCI Arc Fault  \
# unix_ts
# 2016-03-06 08:00:00                 0.0                                5.0
# 2016-03-06 08:00:01                 0.0                                6.0
# 2016-03-06 08:00:02                 0.0                                5.0
#
#                      ...  15 Garage Sub Panel L1  16 Garage Sub Panel L2  \
# unix_ts              ...
# 2016-03-06 08:00:00  ...                     0.0                     0.0
# 2016-03-06 08:00:01  ...                     0.0                     0.0
# 2016-03-06 08:00:02  ...                     0.0                     0.0
#
#                      17 Upstairs Plugs Lights L1  18 Upstairs Plugs Lights L2  \
# unix_ts
# 2016-03-06 08:00:00                          5.0                          4.0
# 2016-03-06 08:00:01                          5.0                          4.0
# 2016-03-06 08:00:02                          5.0                          4.0
#
#                      19 Basement Blue Plugs  20 Bathrooms  \
# unix_ts
# 2016-03-06 08:00:00                    20.0           3.0
# 2016-03-06 08:00:01                    20.0           2.0
# 2016-03-06 08:00:02                    20.0           2.0
#
#                      21 Rental Suite Sub Panel L1  \
# unix_ts
# 2016-03-06 08:00:00                          43.0
# 2016-03-06 08:00:01                          43.0
# 2016-03-06 08:00:02                          44.0
#
#                      22 Rental Suite Sub Panel L2  23 Misc. Plugs  \
# unix_ts
# 2016-03-06 08:00:00                           3.0             0.0
# 2016-03-06 08:00:01                           3.0             0.0
# 2016-03-06 08:00:02                           3.0             0.0
#
#                      24 Home Office
# unix_ts
# 2016-03-06 08:00:00            78.0
# 2016-03-06 08:00:01            78.0
# 2016-03-06 08:00:02            78.0
#
# [3 rows x 27 columns]

# %% [markdown]
# ## Représentations graphiques PART_I

# %%
df = h1pb2.iloc[:,3:].copy()

for i in range(df.shape[1]):
    fig = df[df.columns[i]].plot(figsize=(15,5), title=df.columns[i])
    fig.axes.title.set_size(20)
    plt.show()

# %% [markdown]
# ## Représentations graphiques PART_II

# %%
df1 = h1pb2.iloc[:,2].copy()
fig = df1.plot(figsize=(20,10), title='house_power_blk2 - house 1 - mains')
fig.axes.title.set_size(20)

# %% [markdown]
# ### Manifestement mon ordi n'arrive pas à encaisser le dernier calculs ci-dessous ... :'( ...

# %%
df2 = h1pb2.iloc[:,3:].copy()
fig = df2.plot(figsize=(20,10), title='house_power_blk2 - house 1 - all sub')
fig.axes.title.set_size(20)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3816/175015501.py in <module>
# ----> 1 df2 = h1pb2.iloc[:,3:].copy()
#       2 fig = df2.plot(figsize=(20,10), title='house_power_blk2 - house 1 - all sub')
#       3 fig.axes.title.set_size(20)
#
# D:\anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# D:\anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1508             return self._getitem_lowerdim(tup)
#    1509
# -> 1510         return self._getitem_tuple_same_dim(tup)
#    1511
#    1512     def _get_list_axis(self, key, axis: int):
#
# D:\anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_tuple_same_dim(self, tup)
#     804                 continue
#     805
# --> 806             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     807             # We should never have retval.ndim < self.ndim, as that should
#     808             #  be handled by the _getitem_lowerdim call above.
#
# D:\anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1541
#    1542         if isinstance(key, slice):
# -> 1543             return self._get_slice_axis(key, axis=axis)
#    1544
#    1545         if is_iterator(key):
#
# D:\anaconda\lib\site-packages\pandas\core\indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1577         labels = obj._get_axis(axis)
#    1578         labels._validate_positional_slice(slice_obj)
# -> 1579         return self.obj._slice(slice_obj, axis=axis)
#    1580
#    1581     def _convert_to_indexer(self, key, axis: int, is_setter: bool = False):
#
# D:\anaconda\lib\site-packages\pandas\core\generic.py in _slice(self, slobj, axis)
#    3826         assert isinstance(slobj, slice), type(slobj)
#    3827         axis = self._get_block_manager_axis(axis)
# -> 3828         result = self._constructor(self._mgr.get_slice(slobj, axis=axis))
#    3829         result = result.__finalize__(self)
#    3830
#
# D:\anaconda\lib\site-packages\pandas\_libs\internals.pyx in pandas._libs.internals.BlockManager.get_slice()
#
# D:\anaconda\lib\site-packages\pandas\core\internals\managers.py in _slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice)
#     817                             blocks.append(nb)
#     818                     else:
# --> 819                         nb = blk.take_nd(taker, axis=0, new_mgr_locs=mgr_locs)
#     820                         blocks.append(nb)
#     821
#
# D:\anaconda\lib\site-packages\pandas\core\internals\blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1142             allow_fill = True
#    1143
# -> 1144         new_values = algos.take_nd(
#    1145             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1146         )
#
# D:\anaconda\lib\site-packages\pandas\core\array_algos\take.py in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     106
#     107     arr = np.asarray(arr)
# --> 108     return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     109
#     110
#
# D:\anaconda\lib\site-packages\pandas\core\array_algos\take.py in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     147         out = np.empty(out_shape, dtype=dtype, order="F")
#     148     else:
# --> 149         out = np.empty(out_shape, dtype=dtype)
#     150
#     151     func = _get_take_nd_function(
#
# MemoryError: Unable to allocate 996. MiB for an array with shape (24, 5439600) and data type float64
